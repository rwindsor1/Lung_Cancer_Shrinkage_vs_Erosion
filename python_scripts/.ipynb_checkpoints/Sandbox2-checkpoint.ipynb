# %%
import pandas as pd
import os
import matplotlib.pyplot as plt
# %matplotlib inline
import nibabel as nib

tumour_file = "D:/fullscans/N01"
for file in os.listdir("D:/fullscans/N01"):
    if file.rfind("a.nii"):
        print(file)
# Out:
# 87. LACUNARITY for Image (Ｌ) = ∑Λ₍ɢ₎∕Ǥɴ ∀ ɢ∈Ǥ

# %%
the_path = "D:/boxcountsTest"
count_files = os.listdir(the_path)
print(count_files)
# Out:
# ['boxcount1.txt', 'boxcount2.txt', 'boxcount3.txt', 'boxcount4.txt', 'boxcount5.txt', 'boxcount6.txt']

# %%
# Out:
# [0.015471428571428572, 0.016087755102040815, 0.015889795918367346, 0.01580204081632653, 0.01576326530612245, 0.01579795918367347]
