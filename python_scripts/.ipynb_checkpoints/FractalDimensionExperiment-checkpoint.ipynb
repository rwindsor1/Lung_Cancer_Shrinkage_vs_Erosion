# %%
import pandas as pd
import os
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

df = pd.read_table("D:/fractal-info/fragmenting_sim_fractal_info.txt")
print(df.columns[86])
mode = df[df.columns[87]].mode()[0]
#df.where(df[df.columns[87]]>mode)[df.columns[5]].plot()
df[df.columns[87]].plot()
plt.show()

print(df.columns[0],df.columns[5],df.columns[86])
small_df = pd.DataFrame()
small_df["Image Name"] = df[df.columns[0]]
small_df["Fractal Dim"] = df[df.columns[5]]
small_df["Lacunarity"] = df[df.columns[86]]
small_df.head()
# Out:
# 87. LACUNARITY for Image (Ｌ) = ∑Λ₍ɢ₎∕Ǥɴ ∀ ɢ∈Ǥ
# 1. FracLac 2015Sep090313a9330: File Slice (ROI) start position 6. D̅ = ∑D₍ɢ₎∕Ǥɴ ∀ ɢ∈Ǥ for Dʙ 87. LACUNARITY for Image (Ｌ) = ∑Λ₍ɢ₎∕Ǥɴ ∀ ɢ∈Ǥ
#                                      Image Name  Fractal Dim  Lacunarity
# 0    N01_0_0pngŞ1_ (0, 0_410x410) 0,0--552,552        1.8992         0.0
# 1    N01_0_1pngŞ1_ (0, 0_410x410) 0,0--552,552        1.8992         0.0
# 2   N01_0_10pngŞ1_ (0, 0_410x410) 0,0--552,552        1.8992         0.0
# 3  N01_0_100pngŞ1_ (0, 0_410x410) 0,0--552,552        1.8992         0.0
# 4  N01_0_101pngŞ1_ (0, 0_410x410) 0,0--552,552        1.8992         0.0

# %%
def get_patient(x):
    x = x[0:x.find("_")]
    return x

def get_scan_no(x):
    x = x[x.find("_")+1:]
    x = x[:x.find("_")]
    return int(x)

def get_slice_no(x):
    x = x[x.find("_")+1:]
    x = x[x.find("_")+1:]
    x = x[:x.find("p")]
    return int(x)

small_df["Patient"] = small_df["Image Name"].apply(get_patient)

small_df["Scan No"] = small_df["Image Name"].apply(get_scan_no)

small_df["Slice No"] = small_df["Image Name"].apply(get_slice_no)

small_df.drop([small_df.columns[0]],axis = 1)
# Out:
#        Fractal Dim  Lacunarity Patient  Scan No  Slice No
# 0           1.8992      0.0000     N01        0         0
# 1           1.8992      0.0000     N01        0         1
# 2           1.8992      0.0000     N01        0        10
# 3           1.8992      0.0000     N01        0       100
# 4           1.8992      0.0000     N01        0       101
# 5           1.8992      0.0000     N01        0       102
# 6           1.8992      0.0000     N01        0       103
# 7           1.8992      0.0000     N01        0       104
# 8           1.8992      0.0000     N01        0       105
# 9           1.8992      0.0000     N01        0       106
# 10          1.8992      0.0000     N01        0       107
# 11          1.8992      0.0000     N01        0       108
# 12          1.8992      0.0000     N01        0       109
# 13          1.8992      0.0000     N01        0        11
# 14          1.8992      0.0000     N01        0       110
# 15          1.8992      0.0000     N01        0       111
# 16          1.8992      0.0000     N01        0       112
# 17          1.8992      0.0000     N01        0       113
# 18          1.8992      0.0000     N01        0       114
# 19          1.8992      0.0000     N01        0       115
# 20          1.8992      0.0000     N01        0       116
# 21          1.8992      0.0000     N01        0       117
# 22          1.8992      0.0000     N01        0       118
# 23          1.8992      0.0000     N01        0       119
# 24          1.8992      0.0000     N01        0        12
# 25          1.8992      0.0000     N01        0        13
# 26          1.8992      0.0000     N01        0        14
# 27          1.8992      0.0000     N01        0        15
# 28          1.8992      0.0000     N01        0        16
# 29          1.8992      0.0000     N01        0        17
# ...            ...         ...     ...      ...       ...
# 15149       0.9408     34.5013     T12        3        72
# 15150       0.9483     34.9960     T12        3        73
# 15151       1.8992      0.0000     T12        3        74
# 15152       1.8992      0.0000     T12        3        75
# 15153       1.8992      0.0000     T12        3        76
# 15154       1.8992      0.0000     T12        3        77
# 15155       1.8992      0.0000     T12        3        78
# 15156       1.8992      0.0000     T12        3        79
# 15157       1.8992      0.0000     T12        3         8
# 15158       1.8992      0.0000     T12        3        80
# 15159       1.8992      0.0000     T12        3        81
# 15160       1.8992      0.0000     T12        3        82
# 15161       1.8992      0.0000     T12        3        83
# 15162       1.8992      0.0000     T12        3        84
# 15163       1.8992      0.0000     T12        3        85
# 15164       1.8992      0.0000     T12        3        86
# 15165       1.8992      0.0000     T12        3        87
# 15166       1.8992      0.0000     T12        3        88
# 15167       1.8992      0.0000     T12        3        89
# 15168       1.8992      0.0000     T12        3         9
# 15169       1.8992      0.0000     T12        3        90
# 15170       1.8992      0.0000     T12        3        91
# 15171       1.8992      0.0000     T12        3        92
# 15172       1.8992      0.0000     T12        3        93
# 15173       1.8992      0.0000     T12        3        94
# 15174       1.8992      0.0000     T12        3        95
# 15175       1.8992      0.0000     T12        3        96
# 15176       1.8992      0.0000     T12        3        97
# 15177       1.8992      0.0000     T12        3        98
# 15178       1.8992      0.0000     T12        3        99
#
# [15179 rows x 5 columns]

# %%
file = open("D:/fractal-info/fragmenting_sim_fractal_info_condensed.csv","w")
file.write("Patient, Scan No, Mean Fractal Dimension, Reduced Mean Fractal Dimension, Lacunarity, Reduced Lacunarity\n")
for patient in small_df["Patient"].unique():
    patient_df = small_df[small_df["Patient"] == patient]
    for scan in patient_df["Scan No"].unique():
        scan_df = patient_df[patient_df["Scan No"]==scan]
        fractal_dims = np.array(scan_df["Fractal Dim"])
        lacunarities = np.array(scan_df["Lacunarity"])
        reduced_fractal_dims = fractal_dims[fractal_dims != 1.8992]
        reduced_lacunarities = lacunarities[lacunarities != 0]
        file.write("%s,%s,%s,%s,%s,%s\n" % (patient,str(scan),str(fractal_dims.mean()),
                                            str(reduced_fractal_dims.mean()),str(lacunarities.mean()),
                                            str(reduced_lacunarities.mean())))
       
file.close()
